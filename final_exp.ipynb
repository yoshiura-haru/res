# %% [markdown]
# # 使用するライブラリ

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import tracemalloc

# %%
from common.optimizer import SGD,CGOptimizer
from two_layer_net import TwoLayerNet
from dataset.mnist import load_mnist

# %% [markdown]
# # 評価ログ用変数

# %%
loss_list_SGD = []
time_list_SGD = []
loss_list_CG = []
time_list_CG = []

# %% [markdown]
# # 計算時間・メモリ計測付き学習関数

# %%
def train_with_measurement(
    network,
    optimizer,
    x_train,
    t_train,
    iters_num=1000,
    batch_size=100
):
    train_size = x_train.shape[0]
    loss_list = []

    # ===== メモリ計測開始 =====
    tracemalloc.start()

    # ===== 時間計測開始 =====
    start_time = time.perf_counter()

    for i in range(iters_num):
        batch_mask = np.random.choice(train_size, batch_size)
        # spd_mnist 作成時
        log_spd_train = np.array([
        spd_to_vector(A) for A in spd_train
        ])  # (N, 2500)


        t_batch = t_train[batch_mask]

        grads = network.gradient(x_batch, t_batch)
        optimizer.update(network.params, grads)

        loss = network.loss(x_batch, t_batch)
        loss_list.append(loss)

    # ===== 計測終了 =====
    total_time = time.perf_counter() - start_time
    current, peak = tracemalloc.get_traced_memory()
    tracemalloc.stop()

    return loss_list, total_time, peak

# %% [markdown]
# # 各optimizer実行

# %% [markdown]
# ## MNISTデータ読み込み

# %%
(x_train, t_train), (x_test, t_test) = load_mnist(
    normalize=True,
    one_hot_label=True
)

# %% [markdown]
# ## 初期パラメータ保存

# %%
base_network = TwoLayerNet(
    input_size=784,
    hidden_size=50,
    output_size=10
)

init_params = {k: v.copy() for k, v in base_network.params.items()}

# %% [markdown]
# ## SGD

# %%
network_SGD = TwoLayerNet(2500, 50, 10)
network_SGD.params = {k: v.copy() for k, v in init_params.items()}

optimizer_SGD = SGD(lr=0.01)

loss_list_SGD, time_SGD, peak_SGD = train_with_measurement(
    network_SGD,
    optimizer_SGD,
    x_train,
    t_train,
    iters_num=10000,
    batch_size=100
)
# Out:
# /Users/yoshiuraharu/research2026-1/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:1181: RuntimeWarning: logm result may be inaccurate, approximate err = 8.189014977233455e-08
#   return f(*arrays, *other_args, **kwargs)
# /Users/yoshiuraharu/research2026-1/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:1181: RuntimeWarning: logm result may be inaccurate, approximate err = 6.7561138905603e-08
#   return f(*arrays, *other_args, **kwargs)
# /Users/yoshiuraharu/research2026-1/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:1181: RuntimeWarning: logm result may be inaccurate, approximate err = 6.879574243612296e-08
#   return f(*arrays, *other_args, **kwargs)
# /Users/yoshiuraharu/research2026-1/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:1181: RuntimeWarning: logm result may be inaccurate, approximate err = 1.0766837732489876e-07
#   return f(*arrays, *other_args, **kwargs)
# /Users/yoshiuraharu/research2026-1/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:1181: RuntimeWarning: logm result may be inaccurate, approximate err = 1.6977719496935606e-07
#   return f(*arrays, *other_args, **kwargs)
# /Users/yoshiuraharu/research2026-1/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:1181: RuntimeWarning: logm result may be inaccurate, approximate err = 1.0863860921972446e-07
#   return f(*arrays, *other_args, **kwargs)
# /Users/yoshiuraharu/research2026-1/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:1181: RuntimeWarning: logm result may be inaccurate, approximate err = 1.1510591946262139e-07
#   return f(*arrays, *other_args, **kwargs)
# /Users/yoshiuraharu/research2026-1/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:1181: RuntimeWarning: logm result may be inaccurate, approximate err = 3.771612711034322e-08
#   return f(*arrays, *other_args, **kwargs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 6
#       2 network_SGD.params = {k: v.copy() for k, v in init_params.items()}
#       4 optimizer_SGD = SGD(lr=0.01)
# ----> 6 loss_list_SGD, time_SGD, peak_SGD = train_with_measurement(
#       7     network_SGD,
#       8     optimizer_SGD,
#       9     x_train,
#      10     t_train,
#      11     iters_num=10000,
#      12     batch_size=100
#      13 )
#
# Cell In[37], line 22, in train_with_measurement(network, optimizer, x_train, t_train, iters_num, batch_size)
#      19 batch_mask = np.random.choice(train_size, batch_size)
#      20 # spd_mnist 作成時
#      21 log_spd_train = np.array([
# ---> 22 spd_to_vector(A) for A in spd_train
#      23 ])  # (N, 2500)
#      26 t_batch = t_train[batch_mask]
#      28 grads = network.gradient(x_batch, t_batch)
#
# Cell In[29], line 9, in spd_to_vector(A)
#       4 def spd_to_vector(A):
#       5     """
#       6     A: (d, d) SPD matrix
#       7     return: (d*d,) vector (Log-Euclidean)
#       8     """
# ----> 9     logA = logm(A)
#      10     return logA.flatten().real
#
# File ~/research2026-1/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:1181, in _apply_over_batch.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#    1179 # Early exit if call is not batched
#    1180 if not any(batch_shapes):
# -> 1181     return f(*arrays, *other_args, **kwargs)
#    1183 # Determine broadcasted batch shape
#    1184 batch_shape = np.broadcast_shapes(*batch_shapes)  # Gives OK error message
#
# File ~/research2026-1/.venv/lib/python3.12/site-packages/scipy/linalg/_matfuncs.py:219, in logm(A, disp)
#     217 # Avoid circular import ... this is OK, right?
#     218 import scipy.linalg._matfuncs_inv_ssq
# --> 219 F = scipy.linalg._matfuncs_inv_ssq._logm(A)
#     220 F = _maybe_real(A, F)
#     221 errtol = 1000*eps
#
# File ~/research2026-1/.venv/lib/python3.12/site-packages/scipy/linalg/_matfuncs_inv_ssq.py:871, in _logm(A)
#     869     if np.min(np.diag(A), initial=0.) < 0:
#     870         A = A.astype(complex)
# --> 871     return _logm_triu(A)
#     872 else:
#     873     if keep_it_real:
#
# File ~/research2026-1/.venv/lib/python3.12/site-packages/scipy/linalg/_matfuncs_inv_ssq.py:777, in _logm_triu(T)
#     770 # Define bounds given in Table (2.1).
#     771 theta = (None,
#     772         1.59e-5, 2.31e-3, 1.94e-2, 6.21e-2,
#     773         1.28e-1, 2.06e-1, 2.88e-1, 3.67e-1,
#     774         4.39e-1, 5.03e-1, 5.60e-1, 6.09e-1,
#     775         6.52e-1, 6.89e-1, 7.21e-1, 7.49e-1)
# --> 777 R, s, m = _inverse_squaring_helper(T0, theta)
#     779 # Evaluate U = 2**s r_m(T - I) using the partial fraction expansion (1.1).
#     780 # This requires the nodes and weights
#     781 # corresponding to degree-m Gauss-Legendre quadrature.
#     782 # These quadrature arrays need to be transformed from the [-1, 1] interval
#     783 # to the [0, 1] interval.
#     784 nodes, weights = scipy.special.p_roots(m)
#
# File ~/research2026-1/.venv/lib/python3.12/site-packages/scipy/linalg/_matfuncs_inv_ssq.py:433, in _inverse_squaring_helper(T0, theta)
#     431 for j in range(n):
#     432     a = T0[j, j]
# --> 433     r = _briggs_helper_function(a, s)
#     434     R[j, j] = r
#     435 p = np.exp2(-s)
#
# File ~/research2026-1/.venv/lib/python3.12/site-packages/scipy/linalg/_matfuncs_inv_ssq.py:204, in _briggs_helper_function(a, k)
#     202 for j in range(1, k_hat):
#     203     a = np.sqrt(a)
# --> 204     r = r * (1 + a)
#     205 r = z0 / r
#     206 return r
#
# KeyboardInterrupt:

# %% [markdown]
# # CG法

# %% [markdown]
# ### MNISTをSPD行列に変換

# %%
def mnist_to_spd_lowrank(x, d=50, eps=1e-3):
    """
    x: (784,)
    d: reduced dimension
    """
    x_small = x[:d]
    A = np.outer(x_small, x_small)
    A += eps * np.eye(d)
    return A

# %%
def build_spd_mnist(x, d=50, eps=1e-3):
    """
    x: (N, 784)
    return: (N, d, d)
    """
    N = x.shape[0]
    spd_data = np.zeros((N, d, d), dtype=np.float32)

    for i in range(N):
        spd_data[i] = mnist_to_spd_lowrank(x[i], d, eps)

    return spd_data

# %%
import pickle

(x_train, y_train), (x_test, y_test) = load_mnist()

N = 60000   
d = 50

spd_train = build_spd_mnist(x_train[:N], d=d)

spd_dataset = {
    "spd_train": spd_train,
    "label_train": y_train[:N],
    "d": d
}

with open("spd_mnist.pkl", "wb") as f:
    pickle.dump(spd_dataset, f)

# %%
import numpy as np
from scipy.linalg import logm

def spd_to_vector(A):
    """
    A: (d, d) SPD matrix
    return: (d*d,) vector (Log-Euclidean)
    """
    logA = logm(A)
    return logA.flatten().real

# %% [markdown]
# ### CG法実行

# %%
network_CG = TwoLayerNet(2500, 50, 10)

optimizer_CG = CGOptimizer(
    spd_train,
    cg_iters=3,
    lr=0.1
)

loss_list_CG, time_CG, peak_CG = train_with_measurement(
    network_CG,
    optimizer_CG,
    x_train,   # ← これはインデックス用に使われるだけ
    t_train,
    iters_num=10000,
    batch_size=100
)
# Out:
# /Users/yoshiuraharu/research2026-1/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:1181: RuntimeWarning: logm result may be inaccurate, approximate err = 1.0816604145702513e-07
#   return f(*arrays, *other_args, **kwargs)
# /Users/yoshiuraharu/research2026-1/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:1181: RuntimeWarning: logm result may be inaccurate, approximate err = 6.657926832076555e-08
#   return f(*arrays, *other_args, **kwargs)
# /Users/yoshiuraharu/research2026-1/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:1181: RuntimeWarning: logm result may be inaccurate, approximate err = 2.1268353123105044e-07
#   return f(*arrays, *other_args, **kwargs)
# /Users/yoshiuraharu/research2026-1/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:1181: RuntimeWarning: logm result may be inaccurate, approximate err = 1.3909355800478806e-07
#   return f(*arrays, *other_args, **kwargs)
# /Users/yoshiuraharu/research2026-1/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:1181: RuntimeWarning: logm result may be inaccurate, approximate err = 6.602710378444954e-09
#   return f(*arrays, *other_args, **kwargs)
# /Users/yoshiuraharu/research2026-1/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:1181: RuntimeWarning: logm result may be inaccurate, approximate err = 4.537839970453206e-07
#   return f(*arrays, *other_args, **kwargs)
# /Users/yoshiuraharu/research2026-1/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:1181: RuntimeWarning: logm result may be inaccurate, approximate err = 5.343313773664704e-07
#   return f(*arrays, *other_args, **kwargs)
# /Users/yoshiuraharu/research2026-1/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:1181: RuntimeWarning: logm result may be inaccurate, approximate err = 1.0294409946709493e-07
#   return f(*arrays, *other_args, **kwargs)
# /Users/yoshiuraharu/research2026-1/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:1181: RuntimeWarning: logm result may be inaccurate, approximate err = 1.0431404717792248e-07
#   return f(*arrays, *other_args, **kwargs)
# /Users/yoshiuraharu/research2026-1/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:1181: RuntimeWarning: logm result may be inaccurate, approximate err = 2.402687186986441e-07
#   return f(*arrays, *other_args, **kwargs)
# /Users/yoshiuraharu/research2026-1/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:1181: RuntimeWarning: logm result may be inaccurate, approximate err = 2.525657549767857e-08
#   return f(*arrays, *other_args, **kwargs)
# /Users/yoshiuraharu/research2026-1/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:1181: RuntimeWarning: logm result may be inaccurate, approximate err = 1.440072878722276e-07
#   return f(*arrays, *other_args, **kwargs)
# /Users/yoshiuraharu/research2026-1/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:1181: RuntimeWarning: logm result may be inaccurate, approximate err = 3.4584778063617705e-07
#   return f(*arrays, *other_args, **kwargs)
# /Users/yoshiuraharu/research2026-1/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:1181: RuntimeWarning: logm result may be inaccurate, approximate err = 1.8624280784251823e-08
#   return f(*arrays, *other_args, **kwargs)
# /Users/yoshiuraharu/research2026-1/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:1181: RuntimeWarning: logm result may be inaccurate, approximate err = 1.782275518280585e-07
#   return f(*arrays, *other_args, **kwargs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 9
#       1 network_CG = TwoLayerNet(2500, 50, 10)
#       3 optimizer_CG = CGOptimizer(
#       4     spd_train,
#       5     cg_iters=3,
#       6     lr=0.1
#       7 )
# ----> 9 loss_list_CG, time_CG, peak_CG = train_with_measurement(
#      10     network_CG,
#      11     optimizer_CG,
#      12     x_train,   # ← これはインデックス用に使われるだけ
#      13     t_train,
#      14     iters_num=10000,
#      15     batch_size=100
#      16 )
#
# Cell In[22], line 21, in train_with_measurement(network, optimizer, x_train, t_train, iters_num, batch_size)
#      19 batch_mask = np.random.choice(train_size, batch_size)
#      20 spd_batch = spd_train[batch_mask]
# ---> 21 x_batch = np.array([spd_to_vector(A) for A in spd_batch])
#      23 t_batch = t_train[batch_mask]
#      25 grads = network.gradient(x_batch, t_batch)
#
# Cell In[29], line 9, in spd_to_vector(A)
#       4 def spd_to_vector(A):
#       5     """
#       6     A: (d, d) SPD matrix
#       7     return: (d*d,) vector (Log-Euclidean)
#       8     """
# ----> 9     logA = logm(A)
#      10     return logA.flatten().real
#
# File ~/research2026-1/.venv/lib/python3.12/site-packages/scipy/_lib/_util.py:1181, in _apply_over_batch.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#    1179 # Early exit if call is not batched
#    1180 if not any(batch_shapes):
# -> 1181     return f(*arrays, *other_args, **kwargs)
#    1183 # Determine broadcasted batch shape
#    1184 batch_shape = np.broadcast_shapes(*batch_shapes)  # Gives OK error message
#
# File ~/research2026-1/.venv/lib/python3.12/site-packages/scipy/linalg/_matfuncs.py:219, in logm(A, disp)
#     217 # Avoid circular import ... this is OK, right?
#     218 import scipy.linalg._matfuncs_inv_ssq
# --> 219 F = scipy.linalg._matfuncs_inv_ssq._logm(A)
#     220 F = _maybe_real(A, F)
#     221 errtol = 1000*eps
#
# File ~/research2026-1/.venv/lib/python3.12/site-packages/scipy/linalg/_matfuncs_inv_ssq.py:871, in _logm(A)
#     869     if np.min(np.diag(A), initial=0.) < 0:
#     870         A = A.astype(complex)
# --> 871     return _logm_triu(A)
#     872 else:
#     873     if keep_it_real:
#
# File ~/research2026-1/.venv/lib/python3.12/site-packages/scipy/linalg/_matfuncs_inv_ssq.py:777, in _logm_triu(T)
#     770 # Define bounds given in Table (2.1).
#     771 theta = (None,
#     772         1.59e-5, 2.31e-3, 1.94e-2, 6.21e-2,
#     773         1.28e-1, 2.06e-1, 2.88e-1, 3.67e-1,
#     774         4.39e-1, 5.03e-1, 5.60e-1, 6.09e-1,
#     775         6.52e-1, 6.89e-1, 7.21e-1, 7.49e-1)
# --> 777 R, s, m = _inverse_squaring_helper(T0, theta)
#     779 # Evaluate U = 2**s r_m(T - I) using the partial fraction expansion (1.1).
#     780 # This requires the nodes and weights
#     781 # corresponding to degree-m Gauss-Legendre quadrature.
#     782 # These quadrature arrays need to be transformed from the [-1, 1] interval
#     783 # to the [0, 1] interval.
#     784 nodes, weights = scipy.special.p_roots(m)
#
# File ~/research2026-1/.venv/lib/python3.12/site-packages/scipy/linalg/_matfuncs_inv_ssq.py:429, in _inverse_squaring_helper(T0, theta)
#     422 R = T - np.identity(n)
#     424 # Replace the diagonal and first superdiagonal of T0^(1/(2^s)) - I
#     425 # using formulas that have less subtractive cancellation.
#     426 # Skip this step if the principal branch
#     427 # does not exist at T0; this happens when a diagonal entry of T0
#     428 # is negative with imaginary part 0.
# --> 429 has_principal_branch = all(x.real > 0 or x.imag != 0 for x in np.diag(T0))
#     430 if has_principal_branch:
#     431     for j in range(n):
#
# File ~/research2026-1/.venv/lib/python3.12/site-packages/scipy/linalg/_matfuncs_inv_ssq.py:429, in <genexpr>(.0)
#     422 R = T - np.identity(n)
#     424 # Replace the diagonal and first superdiagonal of T0^(1/(2^s)) - I
#     425 # using formulas that have less subtractive cancellation.
#     426 # Skip this step if the principal branch
#     427 # does not exist at T0; this happens when a diagonal entry of T0
#     428 # is negative with imaginary part 0.
# --> 429 has_principal_branch = all(x.real > 0 or x.imag != 0 for x in np.diag(T0))
#     430 if has_principal_branch:
#     431     for j in range(n):
#
# KeyboardInterrupt:

# %% [markdown]
# # 評価指標の算出

# %%
# 最終的な損失値、収束速度の計算
final_loss_SGD = loss_list_SGD[-1]
final_loss_CG = loss_list_CG[-1]

# 収束判定のための閾値設定
target_loss = 1.0

# 収束速度の計算
convergence_iter_SGD = next(
    (i for i, l in enumerate(loss_list_SGD) if l < target_loss),
    None
)

convergence_iter_CG = next(
    (i for i, l in enumerate(loss_list_CG) if l < target_loss),
    None
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 3
#       1 # 最終的な損失値、収束速度の計算
#       2 final_loss_SGD = loss_list_SGD[-1]
# ----> 3 final_loss_CG = loss_list_CG[-1]
#       5 # 収束判定のための閾値設定
#       6 target_loss = 1.0
#
# IndexError: list index out of range

# %% [markdown]
# # 結果

# %%
print("===== Evaluation =====")

print(f"Final loss (SGD)              : {final_loss_SGD:.4f}")
print(f"Final loss (CG)               : {final_loss_CG:.4f}")

print(f"Convergence iteration (SGD)   : {convergence_iter_SGD}")
print(f"Convergence iteration (CG)    : {convergence_iter_CG}")

print(f"Total time [sec] (SGD)        : {time_SGD:.2f}")
print(f"Total time [sec] (CG)         : {time_CG:.2f}")

print(f"Peak memory [MB] (SGD)        : {peak_SGD / 1024 / 1024:.2f}")
print(f"Peak memory [MB] (CG)         : {peak_CG / 1024 / 1024:.2f}")
